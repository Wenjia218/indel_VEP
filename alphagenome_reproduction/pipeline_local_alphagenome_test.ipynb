# %% [markdown]
# ## Install AlphaGenome
# https://github.com/google-deepmind/alphagenome_research/tree/main

# %%
# !git clone https://github.com/google-deepmind/alphagenome_research.git
# !pip install -e ./alphagenome_research

# %%
import os
import jax

os.environ["JAX_PLATFORM_NAME"] = "gpu"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

print(jax.devices())
print("default backend:", jax.default_backend())
# Out:
# [CudaDevice(id=0)]
# default backend: gpu

# %%
# prepare a exons-only gtf feature file

import pyranges as pr


gtf_path = "data/annotations/gencode.v46.annotation.gtf"
out_path = "data/annotations/gencode.v46.annotation.exon_gene_transcript.gtf.feather"

gtf_df = pr.read_gtf(
    gtf_path,
    as_df=True,
    duplicate_attr=True
)

filtered_gtf = gtf_df[
    (gtf_df["Feature"] == "exon") |
    (gtf_df["Feature"] == "gene") |
    (gtf_df["Feature"] == "transcript")
].copy()

filtered_gtf.to_feather(out_path)

# %%
from alphagenome.data import genome
from alphagenome.visualization import plot_components
from alphagenome_research.model import dna_model
from alphagenome.models import variant_scorers
from alphagenome.models import dna_client

import matplotlib.pyplot as plt
import functools
from typing import Callable
from tqdm import tqdm
import numpy as np
import pandas as pd
from scipy.stats import pearsonr, spearmanr
from sklearn import metrics
from sklearn.metrics import average_precision_score, roc_auc_score

# %%
# Flags to improve determinism.
os.environ['XLA_FLAGS'] = ' '.join([
    '--xla_gpu_deterministic_ops',
    '--xla_gpu_enable_scatter_determinism_expander=True',
    '--xla_gpu_enable_triton_gemm=False',
])
# Increase GPU and CPU memory to reduce out of memory errors.
os.environ['XLA_PYTHON_CLIENT_MEM_FRACTION'] = '0.9'

# %% [markdown]
# ```python
#  dna_model.Organism.HOMO_SAPIENS: OrganismSettings(
#           fasta_path=(
#               'https://storage.googleapis.com/alphagenome/reference/gencode/'
#               'hg38/GRCh38.p13.genome.fa'
#           ),
#           gtf_feather_path=(
#               'https://storage.googleapis.com/alphagenome/reference/gencode/'
#               'hg38/gencode.v46.annotation.gtf.gz.feather'
#           ),
#           pas_feather_path=(
#               'https://storage.googleapis.com/alphagenome/reference/exon/hg38/'
#               'polyadb_human_v3_exon3_contiguous_gtfv46.feather'
#           ),
#           splice_site_starts_feather_path=(
#               'https://storage.googleapis.com/alphagenome/reference/gencode/'
#               'hg38/gencode.v46.splice_sites_starts.feather'
#           ),
#           splice_site_ends_feather_path=(
#               'https://storage.googleapis.com/alphagenome/reference/gencode/'
#               'hg38/gencode.v46.splice_sites_ends.feather'
#           ),
#       ),
# ```

# %%
custom_settings = {
    dna_model.Organism.HOMO_SAPIENS: dna_model.OrganismSettings(
        fasta_path='https://storage.googleapis.com/alphagenome/reference/gencode/'
              'hg38/GRCh38.p13.genome.fa',
        gtf_feather_path="data/annotations/gencode.v46.annotation.exon_gene_transcript.gtf.feather",
        #gtf_feather_path=(
        #      'https://storage.googleapis.com/alphagenome/reference/gencode/'
        #      'hg38/gencode.v46.annotation.gtf.gz.feather'
        # ),
        pas_feather_path=(
              'https://storage.googleapis.com/alphagenome/reference/exon/hg38/'
              'polyadb_human_v3_exon3_contiguous_gtfv46.feather'
          ),
        splice_site_starts_feather_path=(
            'https://storage.googleapis.com/alphagenome/reference/gencode/'
            'hg38/gencode.v46.splice_sites_starts.feather'
        ),
        splice_site_ends_feather_path=(
            'https://storage.googleapis.com/alphagenome/reference/gencode/'
            'hg38/gencode.v46.splice_sites_ends.feather'
        ),
    )
}



model = dna_model.create_from_huggingface(
    "all_folds",
    organism_settings=custom_settings,
)
# Out:
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 12 files:   0%|          | 0/12 [00:00<?, ?it/s]
# /opt/modules/i12g/anaconda/envs/IDPproject_indel_26/lib/python3.11/site-packages/pyfaidx/__init__.py:596: UserWarning: for fsspec: HTTPFileSystem assuming index is current
#   warnings.warn("for fsspec: %s assuming index is current" % type(self._fs).__name__)

# %%
def score_variant(variant_id: str, variant_scorer: Callable) -> pd.DataFrame: 
    
    # variant_id: in the form of chr3_4491276_T_C_b38 or chr3_4491276_T_C
    # variant_scorer: variant_scorers.RECOMMENDED_VARIANT_SCORERS[]

    parts = variant_id.split("_")
    if len(parts) == 5:
        chrom, pos, ref, alt, ext = parts
    elif len(parts) == 4:
        chrom, pos, ref, alt = parts
        ext = None
    else:
        raise ValueError(f"Unexpected variant_id format: {variant_id}")

    # build variant object
    variant = genome.Variant(
        chromosome=chrom,
        position=int(pos),
        reference_bases=ref,
        alternate_bases=alt,
    )
    # Create a 1MB interval centered on the variant.
    interval = variant.reference_interval.resize(2**20)
    
    variant_scores = model.score_variant(
        interval=interval, 
        variant=variant, 
        variant_scorers=[variant_scorer],
        organism=dna_client.Organism.HOMO_SAPIENS,
    )
    variant_scores = variant_scorers.tidy_scores(variant_scores)
    
    return variant_scores

# %% [markdown]
# ## Reproduction of Alphagenome eQTL results

# %%
# import variants from alphagenome source


urls = ["https://storage.googleapis.com/alphagenome/evals/eqtl_variant_borzoi_coefficient_human_predictions.feather",
        "https://storage.googleapis.com/alphagenome/evals/eqtl_variant_catalogue_causality_gene_balanced_human_predictions.feather"]

dfs = [pd.read_feather(url) for url in urls]

df_coefficient = dfs[0]
df_zeroshot = dfs[1]
df_coefficient = df_coefficient.dropna(subset=['target'])
df_zeroshot = df_zeroshot.dropna(subset=['target'])

df_coefficient.head()
# Out:
#              variant_id             gene_id                tissue  prediction  \
# 0  chr3_4491276_T_C_b38   ENSG00000231249.3  Adipose_Subcutaneous    0.101731
# 1  chr3_8733693_G_T_b38   ENSG00000182533.7  Adipose_Subcutaneous    0.014747
# 2  chr3_8963418_C_T_b38  ENSG00000070950.10  Adipose_Subcutaneous   -0.095976
# 3  chr3_9867065_G_C_b38  ENSG00000187288.12  Adipose_Subcutaneous   -0.000609
# 4  chr3_9903375_C_T_b38  ENSG00000163701.19  Adipose_Subcutaneous   -0.035684
#
#      target                                     variant_scorer output_type  \
# 0  0.279811  gene_exons_contained_diff_mean;OutputType.RNA_...     RNA_SEQ
# 1  0.567912  gene_exons_contained_diff_mean;OutputType.RNA_...     RNA_SEQ
# 2 -0.684296  gene_exons_contained_diff_mean;OutputType.RNA_...     RNA_SEQ
# 3 -0.130677  gene_exons_contained_diff_mean;OutputType.RNA_...     RNA_SEQ
# 4 -0.660048  gene_exons_contained_diff_mean;OutputType.RNA_...     RNA_SEQ
#
#                      metric_calculator metric_name
# 0  TissueAggregatedAnnDataCorrelations        None
# 1  TissueAggregatedAnnDataCorrelations        None
# 2  TissueAggregatedAnnDataCorrelations        None
# 3  TissueAggregatedAnnDataCorrelations        None
# 4  TissueAggregatedAnnDataCorrelations        None

# %%
unique_variants = df_coefficient["variant_id"].unique()[:10] # take 10 variants for example

variant_scorer = variant_scorers.RECOMMENDED_VARIANT_SCORERS['RNA_SEQ']  # scorer for RNA seq --> RNA abundance

# %%
variant_scores_dic = {}
for variant in tqdm(unique_variants):
    variant_scores_dic[variant] = score_variant(variant, variant_scorer)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]E0512 21:31:30.044902  744535 xtile_compiler.cc:399] Fusion: gemm_fusion_dot.463 = bf16[32,2048,1024]{1,2,0} fusion(bitcast.8224, bitcast.92, bitcast.94, bitcast.96, bitcast.98), kind=kCustom, calls=gemm_fusion_dot.463_computation.clone, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"fusion_backend_config":{"kind":"__triton_nested_gemm_fusion","block_level_fusion_config":{"num_warps":"8","output_tiles":[{"sizes":["1","128","256"]}],"num_ctas":1,"num_stages":4,"is_tma_allowed":false,"is_warp_specialization_allowed":false}},"force_earliest_schedule":false,"reification_cost":[],"device_type":"DEVICE_TYPE_INVALID"}
# E0512 21:31:30.045057  744535 xtile_compiler.cc:401] Computation: gemm_fusion_dot.463_computation.clone {
#   parameter_1.8 = bf16[32,128,512]{2,1,0} parameter(1)
#   parameter_2.5 = bf16[32,128,512]{2,1,0} parameter(2)
#   parameter_3 = bf16[32,128,512]{2,1,0} parameter(3)
#   parameter_4 = bf16[32,128,512]{2,1,0} parameter(4)
#   concatenate.463 = bf16[32,128,2048]{2,1,0} concatenate(parameter_1.8, parameter_2.5, parameter_3, parameter_4), dimensions={2}
#   parameter_0.8 = bf16[1024,32,128]{2,1,0} parameter(0)
#   ROOT dot.806 = bf16[32,2048,1024]{1,2,0} dot(concatenate.463, parameter_0.8), lhs_batch_dims={0}, lhs_contracting_dims={1}, rhs_batch_dims={1}, rhs_contracting_dims={2}, backend_config={"sizes":["32"]}
# }
# E0512 21:31:30.457088  744548 xtile_compiler.cc:399] Fusion: gemm_fusion_dot.452 = bf16[16384,192]{1,0} fusion(bitcast.1679, bitcast.2089, v_layer____w__.9), kind=kCustom, calls=gemm_fusion_dot.452_computation.clone, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"fusion_backend_config":{"kind":"__triton_nested_gemm_fusion","block_level_fusion_config":{"num_warps":"4","output_tiles":[{"sizes":["64","128"]}],"num_ctas":1,"num_stages":3,"is_tma_allowed":false,"is_warp_specialization_allowed":false}},"force_earliest_schedule":false,"reification_cost":[],"device_type":"DEVICE_TYPE_INVALID"}
# E0512 21:31:30.457207  744548 xtile_compiler.cc:401] Computation: gemm_fusion_dot.452_computation.clone {
#   parameter_0 = bf16[1536,8192]{1,0} parameter(0)
#   parameter_1 = bf16[1536,8192]{1,0} parameter(1)
#   concatenate.458 = bf16[1536,16384]{1,0} concatenate(parameter_0, parameter_1), dimensions={1}
#   bitcast.7773 = bf16[16384,1536]{0,1} bitcast(concatenate.458)
#   parameter_2 = f32[1536,192]{1,0} parameter(2)
#   convert_element_type.5227 = bf16[1536,192]{1,0} convert(parameter_2)
#   ROOT dot.542 = bf16[16384,192]{1,0} dot(bitcast.7773, convert_element_type.5227), lhs_contracting_dims={1}, rhs_contracting_dims={0}, backend_config={"sizes":["64"]}
# }
# E0512 21:31:30.474697  744542 xtile_compiler.cc:399] Fusion: gemm_fusion_dot.452 = bf16[16384,192]{1,0} fusion(bitcast.1679, bitcast.2089, v_layer____w__.9), kind=kCustom, calls=gemm_fusion_dot.452_computation.clone, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"fusion_backend_config":{"kind":"__triton_nested_gemm_fusion","block_level_fusion_config":{"num_warps":"8","output_tiles":[{"sizes":["128","256"]}],"num_ctas":1,"num_stages":4,"is_tma_allowed":false,"is_warp_specialization_allowed":false}},"force_earliest_schedule":false,"reification_cost":[],"device_type":"DEVICE_TYPE_INVALID"}
# E0512 21:31:30.474848  744542 xtile_compiler.cc:401] Computation: gemm_fusion_dot.452_computation.clone {
#   parameter_0 = bf16[1536,8192]{1,0} parameter(0)
#   parameter_1 = bf16[1536,8192]{1,0} parameter(1)
#   concatenate.458 = bf16[1536,16384]{1,0} concatenate(parameter_0, parameter_1), dimensions={1}
#   bitcast.7773 = bf16[16384,1536]{0,1} bitcast(concatenate.458)
#   parameter_2 = f32[1536,192]{1,0} parameter(2)
#   convert_element_type.5227 = bf16[1536,192]{1,0} convert(parameter_2)
#   ROOT dot.542 = bf16[16384,192]{1,0} dot(bitcast.7773, convert_element_type.5227), lhs_contracting_dims={1}, rhs_contracting_dims={0}, backend_config={"sizes":["32"]}
# }
# E0512 21:31:30.739540  744541 xtile_compiler.cc:399] Fusion: gemm_fusion_dot.452 = f32[2,16384,192]{2,1,0} fusion(bitcast.1679, bitcast.2089, bitcast.2), kind=kCustom, calls=gemm_fusion_dot.452_computation.clone, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"fusion_backend_config":{"kind":"__triton_nested_gemm_fusion","block_level_fusion_config":{"num_warps":"4","output_tiles":[{"sizes":["1","64","64"]}],"num_ctas":1,"num_stages":3,"is_tma_allowed":false,"is_warp_specialization_allowed":false}},"force_earliest_schedule":false,"reification_cost":[],"device_type":"DEVICE_TYPE_INVALID"}
# E0512 21:31:30.739680  744541 xtile_compiler.cc:401] Computation: gemm_fusion_dot.452_computation.clone {
#   parameter_0 = bf16[1536,8192]{1,0} parameter(0)
#   parameter_1 = bf16[1536,8192]{1,0} parameter(1)
#   concatenate.458 = bf16[1536,16384]{1,0} concatenate(parameter_0, parameter_1), dimensions={1}
#   bitcast.7773 = bf16[16384,2,768]{0,2,1} bitcast(concatenate.458)
#   parameter_2 = f32[2,768,192]{2,1,0} parameter(2)
#   convert_element_type.5227 = bf16[2,768,192]{2,1,0} convert(parameter_2)
#   ROOT dot = f32[2,16384,192]{2,1,0} dot(bitcast.7773, convert_element_type.5227), lhs_batch_dims={1}, lhs_contracting_dims={2}, rhs_batch_dims={0}, rhs_contracting_dims={1}, backend_config={"sizes":["128"]}
# }
# E0512 21:31:30.878010  744547 xtile_compiler.cc:399] Fusion: gemm_fusion_dot.452 = f32[4,16384,192]{2,1,0} fusion(bitcast.1679, bitcast.2089, bitcast.2), kind=kCustom, calls=gemm_fusion_dot.452_computation.clone, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"fusion_backend_config":{"kind":"__triton_nested_gemm_fusion","block_level_fusion_config":{"num_warps":"8","output_tiles":[{"sizes":["1","128","128"]}],"num_ctas":1,"num_stages":4,"is_tma_allowed":false,"is_warp_specialization_allowed":false}},"force_earliest_schedule":false,"reification_cost":[],"device_type":"DEVICE_TYPE_INVALID"}
# E0512 21:31:30.878116  744547 xtile_compiler.cc:401] Computation: gemm_fusion_dot.452_computation.clone {
#   parameter_0 = bf16[1536,8192]{1,0} parameter(0)
#   parameter_1 = bf16[1536,8192]{1,0} parameter(1)
#   concatenate.458 = bf16[1536,16384]{1,0} concatenate(parameter_0, parameter_1), dimensions={1}
#   bitcast.7773 = bf16[16384,4,384]{0,2,1} bitcast(concatenate.458)
#   parameter_2 = f32[4,384,192]{2,1,0} parameter(2)
#   convert_element_type.5227 = bf16[4,384,192]{2,1,0} convert(parameter_2)
#   ROOT dot = f32[4,16384,192]{2,1,0} dot(bitcast.7773, convert_element_type.5227), lhs_batch_dims={1}, lhs_contracting_dims={2}, rhs_batch_dims={0}, rhs_contracting_dims={1}, backend_config={"sizes":["32"]}
# }
# E0512 21:31:30.917459  744545 xtile_compiler.cc:399] Fusion: gemm_fusion_dot.452 = f32[2,16384,192]{2,1,0} fusion(bitcast.1679, bitcast.2089, bitcast.2), kind=kCustom, calls=gemm_fusion_dot.452_computation.clone, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"fusion_backend_config":{"kind":"__triton_nested_gemm_fusion","block_level_fusion_config":{"num_warps":"4","output_tiles":[{"sizes":["1","64","64"]}],"num_ctas":1,"num_stages":4,"is_tma_allowed":false,"is_warp_specialization_allowed":false}},"force_earliest_schedule":false,"reification_cost":[],"device_type":"DEVICE_TYPE_INVALID"}
# E0512 21:31:30.917547  744545 xtile_compiler.cc:401] Computation: gemm_fusion_dot.452_computation.clone {
#   parameter_0 = bf16[1536,8192]{1,0} parameter(0)
#   parameter_1 = bf16[1536,8192]{1,0} parameter(1)
#   concatenate.458 = bf16[1536,16384]{1,0} concatenate(parameter_0, parameter_1), dimensions={1}
#   bitcast.7773 = bf16[16384,2,768]{0,2,1} bitcast(concatenate.458)
#   parameter_2 = f32[2,768,192]{2,1,0} parameter(2)
#   convert_element_type.5227 = bf16[2,768,192]{2,1,0} convert(parameter_2)
#   ROOT dot = f32[2,16384,192]{2,1,0} dot(bitcast.7773, convert_element_type.5227), lhs_batch_dims={1}, lhs_contracting_dims={2}, rhs_batch_dims={0}, rhs_contracting_dims={1}, backend_config={"sizes":["64"]}
# }
# E0512 21:31:31.018606  744545 xtile_compiler.cc:399] Fusion: gemm_fusion_dot.453 = f32[8,16384,128]{2,1,0} fusion(bitcast.1679, bitcast.2089, bitcast.2), kind=kCustom, calls=gemm_fusion_dot.453_computation.clone, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"fusion_backend_config":{"kind":"__triton_nested_gemm_fusion","block_level_fusion_config":{"num_warps":"8","output_tiles":[{"sizes":["1","128","128"]}],"num_ctas":1,"num_stages":4,"is_tma_allowed":false,"is_warp_specialization_allowed":false}},"force_earliest_schedule":false,"reification_cost":[],"device_type":"DEVICE_TYPE_INVALID"}
# E0512 21:31:31.018684  744545 xtile_compiler.cc:401] Computation: gemm_fusion_dot.453_computation.clone {
#   parameter_0.1 = bf16[1536,8192]{1,0} parameter(0)
#   parameter_1.1 = bf16[1536,8192]{1,0} parameter(1)
#   concatenate.459 = bf16[1536,16384]{1,0} concatenate(parameter_0.1, parameter_1.1), dimensions={1}
#   bitcast.7774 = bf16[16384,8,192]{0,2,1} bitcast(concatenate.459)
#   parameter_2.1 = f32[8,192,128]{2,1,0} parameter(2)
#   convert_element_type.5228 = bf16[8,192,128]{2,1,0} convert(parameter_2.1)
#   ROOT dot = f32[8,16384,128]{2,1,0} dot(bitcast.7774, convert_element_type.5228), lhs_batch_dims={1}, lhs_contracting_dims={2}, rhs_batch_dims={0}, rhs_contracting_dims={1}, backend_config={"sizes":["32"]}
# }
# E0512 21:31:31.279476  744539 xtile_compiler.cc:399] Fusion: gemm_fusion_dot.452 = bf16[16384,192]{1,0} fusion(bitcast.1679, bitcast.2089, v_layer____w__.9), kind=kCustom, calls=gemm_fusion_dot.452_computation.clone, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"fusion_backend_config":{"kind":"__triton_nested_gemm_fusion","block_level_fusion_config":{"num_warps":"2","output_tiles":[{"sizes":["64","32"]}],"num_ctas":1,"num_stages":3,"is_tma_allowed":false,"is_warp_specialization_allowed":false}},"force_earliest_schedule":false,"reification_cost":[],"device_type":"DEVICE_TYPE_INVALID"}
# E0512 21:31:31.279610  744539 xtile_compiler.cc:401] Computation: gemm_fusion_dot.452_computation.clone {
#   parameter_0 = bf16[1536,8192]{1,0} parameter(0)
#   parameter_1 = bf16[1536,8192]{1,0} parameter(1)
#   concatenate.458 = bf16[1536,16384]{1,0} concatenate(parameter_0, parameter_1), dimensions={1}
#   bitcast.7773 = bf16[16384,1536]{0,1} bitcast(concatenate.458)
#   parameter_2 = f32[1536,192]{1,0} parameter(2)
#   convert_element_type.5227 = bf16[1536,192]{1,0} convert(parameter_2)
#   ROOT dot.542 = bf16[16384,192]{1,0} dot(bitcast.7773, convert_element_type.5227), lhs_contracting_dims={1}, rhs_contracting_dims={0}, backend_config={"sizes":["128"]}
# }
# E0512 21:31:31.741219  744536 xtile_compiler.cc:399] Fusion: gemm_fusion_dot.453 = bf16[16384,128]{1,0} fusion(bitcast.1679, bitcast.2089, k_layer____w__.9), kind=kCustom, calls=gemm_fusion_dot.453_computation.clone, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"fusion_backend_config":{"kind":"__triton_nested_gemm_fusion","block_level_fusion_config":{"num_warps":"4","output_tiles":[{"sizes":["64","128"]}],"num_ctas":1,"num_stages":4,"is_tma_allowed":false,"is_warp_specialization_allowed":false}},"force_earliest_schedule":false,"reification_cost":[],"device_type":"DEVICE_TYPE_INVALID"}
# E0512 21:31:31.741316  744536 xtile_compiler.cc:401] Computation: gemm_fusion_dot.453_computation.clone {
#   parameter_0.1 = bf16[1536,8192]{1,0} parameter(0)
#   parameter_1.1 = bf16[1536,8192]{1,0} parameter(1)
#   concatenate.459 = bf16[1536,16384]{1,0} concatenate(parameter_0.1, parameter_1.1), dimensions={1}
#   bitcast.7774 = bf16[16384,1536]{0,1} bitcast(concatenate.459)
#   parameter_2.1 = f32[1536,128]{1,0} parameter(2)
#   convert_element_type.5228 = bf16[1536,128]{1,0} convert(parameter_2.1)
#   ROOT dot.543 = bf16[16384,128]{1,0} dot(bitcast.7774, convert_element_type.5228), lhs_contracting_dims={1}, rhs_contracting_dims={0}, backend_config={"sizes":["32"]}
# }
# E0512 21:31:31.845863  744547 xtile_compiler.cc:399] Fusion: gemm_fusion_dot.453 = bf16[16384,128]{1,0} fusion(bitcast.1679, bitcast.2089, k_layer____w__.9), kind=kCustom, calls=gemm_fusion_dot.453_computation.clone, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"fusion_backend_config":{"kind":"__triton_nested_gemm_fusion","block_level_fusion_config":{"num_warps":"8","output_tiles":[{"sizes":["128","128"]}],"num_ctas":1,"num_stages":4,"is_tma_allowed":false,"is_warp_specialization_allowed":false}},"force_earliest_schedule":false,"reification_cost":[],"device_type":"DEVICE_TYPE_INVALID"}
# E0512 21:31:31.845993  744547 xtile_compiler.cc:401] Computation: gemm_fusion_dot.453_computation.clone {
#   parameter_0.1 = bf16[1536,8192]{1,0} parameter(0)
#   parameter_1.1 = bf16[1536,8192]{1,0} parameter(1)
#   concatenate.459 = bf16[1536,16384]{1,0} concatenate(parameter_0.1, parameter_1.1), dimensions={1}
#   bitcast.7774 = bf16[16384,1536]{0,1} bitcast(concatenate.459)
#   parameter_2.1 = f32[1536,128]{1,0} parameter(2)
#   convert_element_type.5228 = bf16[1536,128]{1,0} convert(parameter_2.1)
#   ROOT dot.543 = bf16[16384,128]{1,0} dot(bitcast.7774, convert_element_type.5228), lhs_contracting_dims={1}, rhs_contracting_dims={0}, backend_config={"sizes":["32"]}
# }
# E0512 21:31:31.951508  744546 xtile_compiler.cc:399] Fusion: gemm_fusion_dot.453 = bf16[16384,128]{1,0} fusion(bitcast.1679, bitcast.2089, k_layer____w__.9), kind=kCustom, calls=gemm_fusion_dot.453_computation.clone, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"fusion_backend_config":{"kind":"__triton_nested_gemm_fusion","block_level_fusion_config":{"num_warps":"4","output_tiles":[{"sizes":["64","128"]}],"num_ctas":1,"num_stages":3,"is_tma_allowed":false,"is_warp_specialization_allowed":false}},"force_earliest_schedule":false,"reification_cost":[],"device_type":"DEVICE_TYPE_INVALID"}
# E0512 21:31:31.951620  744546 xtile_compiler.cc:401] Computation: gemm_fusion_dot.453_computation.clone {
#   parameter_0.1 = bf16[1536,8192]{1,0} parameter(0)
#   parameter_1.1 = bf16[1536,8192]{1,0} parameter(1)
#   concatenate.459 = bf16[1536,16384]{1,0} concatenate(parameter_0.1, parameter_1.1), dimensions={1}
#   bitcast.7774 = bf16[16384,1536]{0,1} bitcast(concatenate.459)
#   parameter_2.1 = f32[1536,128]{1,0} parameter(2)
#   convert_element_type.5228 = bf16[1536,128]{1,0} convert(parameter_2.1)
#   ROOT dot.543 = bf16[16384,128]{1,0} dot(bitcast.7774, convert_element_type.5228), lhs_contracting_dims={1}, rhs_contracting_dims={0}, backend_config={"sizes":["64"]}
# }
# E0512 21:31:31.959503  744547 xtile_compiler.cc:399] Fusion: gemm_fusion_dot.453 = f32[2,16384,128]{2,1,0} fusion(bitcast.1679, bitcast.2089, bitcast.2), kind=kCustom, calls=gemm_fusion_dot.453_computation.clone, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"fusion_backend_config":{"kind":"__triton_nested_gemm_fusion","block_level_fusion_config":{"num_warps":"4","output_tiles":[{"sizes":["1","64","64"]}],"num_ctas":1,"num_stages":4,"is_tma_allowed":false,"is_warp_specialization_allowed":false}},"force_earliest_schedule":false,"reification_cost":[],"device_type":"DEVICE_TYPE_INVALID"}
# E0512 21:31:31.959579  744547 xtile_compiler.cc:401] Computation: gemm_fusion_dot.453_computation.clone {
#   parameter_0.1 = bf16[1536,8192]{1,0} parameter(0)
#   parameter_1.1 = bf16[1536,8192]{1,0} parameter(1)
#   concatenate.459 = bf16[1536,16384]{1,0} concatenate(parameter_0.1, parameter_1.1), dimensions={1}
#   bitcast.7774 = bf16[16384,2,768]{0,2,1} bitcast(concatenate.459)
#   parameter_2.1 = f32[2,768,128]{2,1,0} parameter(2)
#   convert_element_type.5228 = bf16[2,768,128]{2,1,0} convert(parameter_2.1)
#   ROOT dot = f32[2,16384,128]{2,1,0} dot(bitcast.7774, convert_element_type.5228), lhs_batch_dims={1}, lhs_contracting_dims={2}, rhs_batch_dims={0}, rhs_contracting_dims={1}, backend_config={"sizes":["64"]}
# }
# E0512 21:31:32.285746  744541 xtile_compiler.cc:399] Fusion: gemm_fusion_dot.453 = bf16[16384,128]{1,0} fusion(bitcast.1679, bitcast.2089, k_layer____w__.9), kind=kCustom, calls=gemm_fusion_dot.453_computation.clone, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"fusion_backend_config":{"kind":"__triton_nested_gemm_fusion","block_level_fusion_config":{"num_warps":"2","output_tiles":[{"sizes":["64","32"]}],"num_ctas":1,"num_stages":3,"is_tma_allowed":false,"is_warp_specialization_allowed":false}},"force_earliest_schedule":false,"reification_cost":[],"device_type":"DEVICE_TYPE_INVALID"}
# E0512 21:31:32.285896  744541 xtile_compiler.cc:401] Computation: gemm_fusion_dot.453_computation.clone {
#   parameter_0.1 = bf16[1536,8192]{1,0} parameter(0)
#   parameter_1.1 = bf16[1536,8192]{1,0} parameter(1)
#   concatenate.459 = bf16[1536,16384]{1,0} concatenate(parameter_0.1, parameter_1.1), dimensions={1}
#   bitcast.7774 = bf16[16384,1536]{0,1} bitcast(concatenate.459)
#   parameter_2.1 = f32[1536,128]{1,0} parameter(2)
#   convert_element_type.5228 = bf16[1536,128]{1,0} convert(parameter_2.1)
#   ROOT dot.543 = bf16[16384,128]{1,0} dot(bitcast.7774, convert_element_type.5228), lhs_contracting_dims={1}, rhs_contracting_dims={0}, backend_config={"sizes":["128"]}
# }
# E0512 21:31:32.514236  744537 xtile_compiler.cc:399] Fusion: gemm_fusion_dot.452 = bf16[16384,192]{1,0} fusion(bitcast.1679, bitcast.2089, v_layer____w__.9), kind=kCustom, calls=gemm_fusion_dot.452_computation.clone, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"fusion_backend_config":{"kind":"__triton_nested_gemm_fusion","block_level_fusion_config":{"num_warps":"4","output_tiles":[{"sizes":["64","64"]}],"num_ctas":1,"num_stages":4,"is_tma_allowed":false,"is_warp_specialization_allowed":false}},"force_earliest_schedule":false,"reification_cost":[],"device_type":"DEVICE_TYPE_INVALID"}
# E0512 21:31:32.514313  744537 xtile_compiler.cc:401] Computation: gemm_fusion_dot.452_computation.clone {
#   parameter_0 = bf16[1536,8192]{1,0} parameter(0)
#   parameter_1 = bf16[1536,8192]{1,0} parameter(1)
#   concatenate.458 = bf16[1536,16384]{1,0} concatenate(parameter_0, parameter_1), dimensions={1}
#   bitcast.7773 = bf16[16384,1536]{0,1} bitcast(concatenate.458)
#   parameter_2 = f32[1536,192]{1,0} parameter(2)
#   convert_element_type.5227 = bf16[1536,192]{1,0} convert(parameter_2)
#   ROOT dot.542 = bf16[16384,192]{1,0} dot(bitcast.7773, convert_element_type.5227), lhs_contracting_dims={1}, rhs_contracting_dims={0}, backend_config={"sizes":["64"]}
# }
# E0512 21:31:32.997767  744542 xtile_compiler.cc:399] Fusion: gemm_fusion_dot.454 = bf16[16384,1024]{1,0} fusion(bitcast.1679, bitcast.2089, q_layer____w__.9), kind=kCustom, calls=gemm_fusion_dot.454_computation.clone, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"fusion_backend_config":{"kind":"__triton_nested_gemm_fusion","block_level_fusion_config":{"num_warps":"8","output_tiles":[{"sizes":["128","256"]}],"num_ctas":1,"num_stages":4,"is_tma_allowed":false,"is_warp_specialization_allowed":false}},"force_earliest_schedule":false,"reification_cost":[],"device_type":"DEVICE_TYPE_INVALID"}
# E0512 21:31:32.997867  744542 xtile_compiler.cc:401] Computation: gemm_fusion_dot.454_computation.clone {
#   parameter_0.2 = bf16[1536,8192]{1,0} parameter(0)
#   parameter_1.2 = bf16[1536,8192]{1,0} parameter(1)
#   concatenate.460 = bf16[1536,16384]{1,0} concatenate(parameter_0.2, parameter_1.2), dimensions={1}
#   bitcast.7775 = bf16[16384,1536]{0,1} bitcast(concatenate.460)
#   parameter_2.2 = f32[1536,1024]{1,0} parameter(2)
#   convert_element_type.5229 = bf16[1536,1024]{1,0} convert(parameter_2.2)
#   ROOT dot.544 = bf16[16384,1024]{1,0} dot(bitcast.7775, convert_element_type.5229), lhs_contracting_dims={1}, rhs_contracting_dims={0}, backend_config={"sizes":["32"]}
# }
# E0512 21:31:33.373631  744545 xtile_compiler.cc:399] Fusion: gemm_fusion_dot.466 = bf16[16384,1536]{0,1} fusion(bitcast.128, bitcast.175, linear_embedding____w__.9), kind=kCustom, calls=gemm_fusion_dot.466_computation.clone, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"fusion_backend_config":{"kind":"__triton_nested_gemm_fusion","block_level_fusion_config":{"num_warps":"4","output_tiles":[{"sizes":["64","64"]}],"num_ctas":1,"num_stages":3,"is_tma_allowed":false,"is_warp_specialization_allowed":false}},"force_earliest_schedule":false,"reification_cost":[],"device_type":"DEVICE_TYPE_INVALID"}
# E0512 21:31:33.373772  744545 xtile_compiler.cc:401] Computation: gemm_fusion_dot.466_computation.clone {
#   parameter_0.33 = bf16[8192,1536]{1,0} parameter(0)
#   parameter_1.33 = bf16[8192,1536]{1,0} parameter(1)
#   concatenate.466 = bf16[16384,1536]{1,0} concatenate(parameter_0.33, parameter_1.33), dimensions={0}
#   parameter_2.8 = f32[1536,1536]{1,0} parameter(2)
#   convert_element_type.5238 = bf16[1536,1536]{1,0} convert(parameter_2.8)
#   ROOT dot.575 = bf16[16384,1536]{0,1} dot(concatenate.466, convert_element_type.5238), lhs_contracting_dims={1}, rhs_contracting_dims={0}, backend_config={"sizes":["128"]}
# }
# E0512 21:31:33.513414  744545 xtile_compiler.cc:399] Fusion: gemm_fusion_dot.455 = bf16[1024,4096]{0,1} fusion(bitcast.2139, bitcast.2157, linear_k____w__.11), kind=kCustom, calls=gemm_fusion_dot.455_computation.clone, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"fusion_backend_config":{"kind":"__triton_nested_gemm_fusion","block_level_fusion_config":{"num_warps":"4","output_tiles":[{"sizes":["64","128"]}],"num_ctas":1,"num_stages":3,"is_tma_allowed":false,"is_warp_specialization_allowed":false}},"force_earliest_schedule":false,"reification_cost":[],"device_type":"DEVICE_TYPE_INVALID"}
# E0512 21:31:33.513520  744545 xtile_compiler.cc:401] Computation: gemm_fusion_dot.455_computation.clone {
#   parameter_0.4 = bf16[1536,512]{1,0} parameter(0)
#   parameter_1.4 = bf16[1536,512]{1,0} parameter(1)
#   concatenate.461 = bf16[1536,1024]{1,0} concatenate(parameter_0.4, parameter_1.4), dimensions={1}
#   bitcast.7780 = bf16[1024,1536]{0,1} bitcast(concatenate.461)
#   parameter_2.3 = f32[1536,4096]{1,0} parameter(2)
#   convert_element_type.5230 = bf16[1536,4096]{1,0} convert(parameter_2.3)
#   ROOT dot.546 = bf16[1024,4096]{0,1} dot(bitcast.7780, convert_element_type.5230), lhs_contracting_dims={1}, rhs_contracting_dims={0}, backend_config={"sizes":["64"]}
# }
# E0512 21:31:34.237098  744546 xtile_compiler.cc:399] Fusion: gemm_fusion_dot.454 = bf16[16384,1024]{1,0} fusion(bitcast.1679, bitcast.2089, q_layer____w__.9), kind=kCustom, calls=gemm_fusion_dot.454_computation.clone, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"fusion_backend_config":{"kind":"__triton_nested_gemm_fusion","block_level_fusion_config":{"num_warps":"4","output_tiles":[{"sizes":["64","64"]}],"num_ctas":1,"num_stages":4,"is_tma_allowed":false,"is_warp_specialization_allowed":false}},"force_earliest_schedule":false,"reification_cost":[],"device_type":"DEVICE_TYPE_INVALID"}
# E0512 21:31:34.237195  744546 xtile_compiler.cc:401] Computation: gemm_fusion_dot.454_computation.clone {
#   parameter_0.2 = bf16[1536,8192]{1,0} parameter(0)
#   parameter_1.2 = bf16[1536,8192]{1,0} parameter(1)
#   concatenate.460 = bf16[1536,16384]{1,0} concatenate(parameter_0.2, parameter_1.2), dimensions={1}
#   bitcast.7775 = bf16[16384,1536]{0,1} bitcast(concatenate.460)
#   parameter_2.2 = f32[1536,1024]{1,0} parameter(2)
#   convert_element_type.5229 = bf16[1536,1024]{1,0} convert(parameter_2.2)
#   ROOT dot.544 = bf16[16384,1024]{1,0} dot(bitcast.7775, convert_element_type.5229), lhs_contracting_dims={1}, rhs_contracting_dims={0}, backend_config={"sizes":["64"]}
# }
# E0512 21:31:34.343114  744537 xtile_compiler.cc:399] Fusion: gemm_fusion_dot.453 = bf16[16384,128]{1,0} fusion(bitcast.1679, bitcast.2089, k_layer____w__.9), kind=kCustom, calls=gemm_fusion_dot.453_computation.clone, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"fusion_backend_config":{"kind":"__triton_nested_gemm_fusion","block_level_fusion_config":{"num_warps":"4","output_tiles":[{"sizes":["64","64"]}],"num_ctas":1,"num_stages":4,"is_tma_allowed":false,"is_warp_specialization_allowed":false}},"force_earliest_schedule":false,"reification_cost":[],"device_type":"DEVICE_TYPE_INVALID"}
# E0512 21:31:34.343199  744537 xtile_compiler.cc:401] Computation: gemm_fusion_dot.453_computation.clone {
#   parameter_0.1 = bf16[1536,8192]{1,0} parameter(0)
#   parameter_1.1 = bf16[1536,8192]{1,0} parameter(1)
#   concatenate.459 = bf16[1536,16384]{1,0} concatenate(parameter_0.1, parameter_1.1), dimensions={1}
#   bitcast.7774 = bf16[16384,1536]{0,1} bitcast(concatenate.459)
#   parameter_2.1 = f32[1536,128]{1,0} parameter(2)
#   convert_element_type.5228 = bf16[1536,128]{1,0} convert(parameter_2.1)
#   ROOT dot.543 = bf16[16384,128]{1,0} dot(bitcast.7774, convert_element_type.5228), lhs_contracting_dims={1}, rhs_contracting_dims={0}, backend_config={"sizes":["64"]}
# }
# E0512 21:31:34.502079  744537 xtile_compiler.cc:399] Fusion: gemm_fusion_dot.453 = bf16[16384,128]{1,0} fusion(bitcast.1679, bitcast.2089, k_layer____w__.9), kind=kCustom, calls=gemm_fusion_dot.453_computation.clone, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"fusion_backend_config":{"kind":"__triton_nested_gemm_fusion","block_level_fusion_config":{"num_warps":"8","output_tiles":[{"sizes":["128","128"]}],"num_ctas":1,"num_stages":4,"is_tma_allowed":false,"is_warp_specialization_allowed":false}},"force_earliest_schedule":false,"reification_cost":[],"device_type":"DEVICE_TYPE_INVALID"}
# E0512 21:31:34.502183  744537 xtile_compiler.cc:401] Computation: gemm_fusion_dot.453_computation.clone {
#   parameter_0.1 = bf16[1536,8192]{1,0} parameter(0)
#   parameter_1.1 = bf16[1536,8192]{1,0} parameter(1)
#   concatenate.459 = bf16[1536,16384]{1,0} concatenate(parameter_0.1, parameter_1.1), dimensions={1}
#   bitcast.7774 = bf16[16384,1536]{0,1} bitcast(concatenate.459)
#   parameter_2.1 = f32[1536,128]{1,0} parameter(2)
#   convert_element_type.5228 = bf16[1536,128]{1,0} convert(parameter_2.1)
#   ROOT dot.543 = bf16[16384,128]{1,0} dot(bitcast.7774, convert_element_type.5228), lhs_contracting_dims={1}, rhs_contracting_dims={0}, backend_config={"sizes":["64"]}
# }
# E0512 21:31:34.525463  744545 xtile_compiler.cc:399] Fusion: gemm_fusion_dot.464 = f32[8,1024,128]{2,1,0} fusion(bitcast.2239, bitcast.2264, bitcast.2), kind=kCustom, calls=gemm_fusion_dot.464_computation.clone, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"fusion_backend_config":{"kind":"__triton_nested_gemm_fusion","block_level_fusion_config":{"num_warps":"4","output_tiles":[{"sizes":["1","64","128"]}],"num_ctas":1,"num_stages":3,"is_tma_allowed":false,"is_warp_specialization_allowed":false}},"force_earliest_schedule":false,"reification_cost":[],"device_type":"DEVICE_TYPE_INVALID"}
# E0512 21:31:34.526006  744545 xtile_compiler.cc:401] Computation: gemm_fusion_dot.464_computation.clone {
#   parameter_0.10 = bf16[1536,512]{1,0} parameter(0)
#   parameter_1.10 = bf16[1536,512]{1,0} parameter(1)
#   concatenate.464 = bf16[1536,1024]{1,0} concatenate(parameter_0.10, parameter_1.10), dimensions={1}
#   bitcast.7787 = bf16[1024,8,192]{0,2,1} bitcast(concatenate.464)
#   parameter_2.6 = f32[8,192,128]{2,1,0} parameter(2)
#   convert_element_type.5232 = bf16[8,192,128]{2,1,0} convert(parameter_2.6)
#   ROOT dot = f32[8,1024,128]{2,1,0} dot(bitcast.7787, convert_element_type.5232), lhs_batch_dims={1}, lhs_contracting_dims={2}, rhs_batch_dims={0}, rhs_contracting_dims={1}, backend_config={"sizes":["64"]}
# }
# E0512 21:31:34.694108  744537 xtile_compiler.cc:399] Fusion: gemm_fusion_dot.453 = f32[2,16384,128]{2,1,0} fusion(bitcast.1679, bitcast.2089, bitcast.2), kind=kCustom, calls=gemm_fusion_dot.453_computation.clone, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"fusion_backend_config":{"kind":"__triton_nested_gemm_fusion","block_level_fusion_config":{"num_warps":"4","output_tiles":[{"sizes":["1","64","64"]}],"num_ctas":1,"num_stages":3,"is_tma_allowed":false,"is_warp_specialization_allowed":false}},"force_earliest_schedule":false,"reification_cost":[],"device_type":"DEVICE_TYPE_INVALID"}
# E0512 21:31:34.694233  744537 xtile_compiler.cc:401] Computation: gemm_fusion_dot.453_computation.clone {
#   parameter_0.1 = bf16[1536,8192]{1,0} parameter(0)
#   parameter_1.1 = bf16[1536,8192]{1,0} parameter(1)
#   concatenate.459 = bf16[1536,16384]{1,0} concatenate(parameter_0.1, parameter_1.1), dimensions={1}
#   bitcast.7774 = bf16[16384,2,768]{0,2,1} bitcast(concatenate.459)
#   parameter_2.1 = f32[2,768,128]{2,1,0} parameter(2)
#   convert_element_type.5228 = bf16[2,768,128]{2,1,0} convert(parameter_2.1)
#   ROOT dot = f32[2,16384,128]{2,1,0} dot(bitcast.7774, convert_element_type.5228), lhs_batch_dims={1}, lhs_contracting_dims={2}, rhs_batch_dims={0}, rhs_contracting_dims={1}, backend_config={"sizes":["128"]}
# }
# E0512 21:31:35.429279  744545 xtile_compiler.cc:399] Fusion: gemm_fusion_dot.464 = f32[4,1024,128]{2,1,0} fusion(bitcast.2239, bitcast.2264, bitcast.2), kind=kCustom, calls=gemm_fusion_dot.464_computation.clone, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"fusion_backend_config":{"kind":"__triton_nested_gemm_fusion","block_level_fusion_config":{"num_warps":"4","output_tiles":[{"sizes":["1","64","64"]}],"num_ctas":1,"num_stages":4,"is_tma_allowed":false,"is_warp_specialization_allowed":false}},"force_earliest_schedule":false,"reification_cost":[],"device_type":"DEVICE_TYPE_INVALID"}
# E0512 21:31:35.429382  744545 xtile_compiler.cc:401] Computation: gemm_fusion_dot.464_computation.clone {
#   parameter_0.10 = bf16[1536,512]{1,0} parameter(0)
#   parameter_1.10 = bf16[1536,512]{1,0} parameter(1)
#   concatenate.464 = bf16[1536,1024]{1,0} concatenate(parameter_0.10, parameter_1.10), dimensions={1}
#   bitcast.7787 = bf16[1024,4,384]{0,2,1} bitcast(concatenate.464)
#   parameter_2.6 = f32[4,384,128]{2,1,0} parameter(2)
#   convert_element_type.5232 = bf16[4,384,128]{2,1,0} convert(parameter_2.6)
#   ROOT dot = f32[4,1024,128]{2,1,0} dot(bitcast.7787, convert_element_type.5232), lhs_batch_dims={1}, lhs_contracting_dims={2}, rhs_batch_dims={0}, rhs_contracting_dims={1}, backend_config={"sizes":["64"]}
# }
# E0512 21:31:35.656976  744550 xtile_compiler.cc:399] Fusion: gemm_fusion_dot.464 = f32[2,1024,128]{2,1,0} fusion(bitcast.2239, bitcast.2264, bitcast.2), kind=kCustom, calls=gemm_fusion_dot.464_computation.clone, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"fusion_backend_config":{"kind":"__triton_nested_gemm_fusion","block_level_fusion_config":{"num_warps":"2","output_tiles":[{"sizes":["1","64","32"]}],"num_ctas":1,"num_stages":3,"is_tma_allowed":false,"is_warp_specialization_allowed":false}},"force_earliest_schedule":false,"reification_cost":[],"device_type":"DEVICE_TYPE_INVALID"}
# E0512 21:31:35.657115  744550 xtile_compiler.cc:401] Computation: gemm_fusion_dot.464_computation.clone {
#   parameter_0.10 = bf16[1536,512]{1,0} parameter(0)
#   parameter_1.10 = bf16[1536,512]{1,0} parameter(1)
#   concatenate.464 = bf16[1536,1024]{1,0} concatenate(parameter_0.10, parameter_1.10), dimensions={1}
#   bitcast.7787 = bf16[1024,2,768]{0,2,1} bitcast(concatenate.464)
#   parameter_2.6 = f32[2,768,128]{2,1,0} parameter(2)
#   convert_element_type.5232 = bf16[2,768,128]{2,1,0} convert(parameter_2.6)
#   ROOT dot = f32[2,1024,128]{2,1,0} dot(bitcast.7787, convert_element_type.5232), lhs_batch_dims={1}, lhs_contracting_dims={2}, rhs_batch_dims={0}, rhs_contracting_dims={1}, backend_config={"sizes":["128"]}
# }
# E0512 21:31:36.231224  744547 xtile_compiler.cc:399] Fusion: gemm_fusion_dot.455 = bf16[1024,4096]{0,1} fusion(bitcast.2139, bitcast.2157, linear_k____w__.11), kind=kCustom, calls=gemm_fusion_dot.455_computation.clone, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"fusion_backend_config":{"kind":"__triton_nested_gemm_fusion","block_level_fusion_config":{"num_warps":"2","output_tiles":[{"sizes":["64","32"]}],"num_ctas":1,"num_stages":3,"is_tma_allowed":false,"is_warp_specialization_allowed":false}},"force_earliest_schedule":false,"reification_cost":[],"device_type":"DEVICE_TYPE_INVALID"}
# E0512 21:31:36.231369  744547 xtile_compiler.cc:401] Computation: gemm_fusion_dot.455_computation.clone {
#   parameter_0.4 = bf16[1536,512]{1,0} parameter(0)
#   parameter_1.4 = bf16[1536,512]{1,0} parameter(1)
#   concatenate.461 = bf16[1536,1024]{1,0} concatenate(parameter_0.4, parameter_1.4), dimensions={1}
#   bitcast.7780 = bf16[1024,1536]{0,1} bitcast(concatenate.461)
#   parameter_2.3 = f32[1536,4096]{1,0} parameter(2)
#   convert_element_type.5230 = bf16[1536,4096]{1,0} convert(parameter_2.3)
#   ROOT dot.546 = bf16[1024,4096]{0,1} dot(bitcast.7780, convert_element_type.5230), lhs_contracting_dims={1}, rhs_contracting_dims={0}, backend_config={"sizes":["128"]}
# }
# E0512 21:31:36.386076  744547 xtile_compiler.cc:399] Fusion: gemm_fusion_dot.455 = bf16[1024,4096]{0,1} fusion(bitcast.2139, bitcast.2157, linear_k____w__.11), kind=kCustom, calls=gemm_fusion_dot.455_computation.clone, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"fusion_backend_config":{"kind":"__triton_nested_gemm_fusion","block_level_fusion_config":{"num_warps":"8","output_tiles":[{"sizes":["128","256"]}],"num_ctas":1,"num_stages":4,"is_tma_allowed":false,"is_warp_specialization_allowed":false}},"force_earliest_schedule":false,"reification_cost":[],"device_type":"DEVICE_TYPE_INVALID"}
# E0512 21:31:36.386194  744547 xtile_compiler.cc:401] Computation: gemm_fusion_dot.455_computation.clone {
#   parameter_0.4 = bf16[1536,512]{1,0} parameter(0)
#   parameter_1.4 = bf16[1536,512]{1,0} parameter(1)
#   concatenate.461 = bf16[1536,1024]{1,0} concatenate(parameter_0.4, parameter_1.4), dimensions={1}
#   bitcast.7780 = bf16[1024,1536]{0,1} bitcast(concatenate.461)
#   parameter_2.3 = f32[1536,4096]{1,0} parameter(2)
#   convert_element_type.5230 = bf16[1536,4096]{1,0} convert(parameter_2.3)
#   ROOT dot.546 = bf16[1024,4096]{0,1} dot(bitcast.7780, convert_element_type.5230), lhs_contracting_dims={1}, rhs_contracting_dims={0}, backend_config={"sizes":["32"]}
# }
# E0512 21:31:36.439366  744540 xtile_compiler.cc:399] Fusion: gemm_fusion_dot.466 = bf16[16384,1536]{0,1} fusion(bitcast.128, bitcast.175, linear_embedding____w__.9), kind=kCustom, calls=gemm_fusion_dot.466_computation.clone, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"fusion_backend_config":{"kind":"__triton_nested_gemm_fusion","block_level_fusion_config":{"num_warps":"8","output_tiles":[{"sizes":["128","128"]}],"num_ctas":1,"num_stages":4,"is_tma_allowed":false,"is_warp_specialization_allowed":false}},"force_earliest_schedule":false,"reification_cost":[],"device_type":"DEVICE_TYPE_INVALID"}
# E0512 21:31:36.439461  744540 xtile_compiler.cc:401] Computation: gemm_fusion_dot.466_computation.clone {
#   parameter_0.33 = bf16[8192,1536]{1,0} parameter(0)
#   parameter_1.33 = bf16[8192,1536]{1,0} parameter(1)
#   concatenate.466 = bf16[16384,1536]{1,0} concatenate(parameter_0.33, parameter_1.33), dimensions={0}
#   parameter_2.8 = f32[1536,1536]{1,0} parameter(2)
#   convert_element_type.5238 = bf16[1536,1536]{1,0} convert(parameter_2.8)
#   ROOT dot.575 = bf16[16384,1536]{0,1} dot(concatenate.466, convert_element_type.5238), lhs_contracting_dims={1}, rhs_contracting_dims={0}, backend_config={"sizes":["32"]}
# }
# E0512 21:31:36.451552  744538 xtile_compiler.cc:399] Fusion: gemm_fusion_dot.455 = bf16[1024,4096]{0,1} fusion(bitcast.2139, bitcast.2157, linear_k____w__.11), kind=kCustom, calls=gemm_fusion_dot.455_computation.clone, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"fusion_backend_config":{"kind":"__triton_nested_gemm_fusion","block_level_fusion_config":{"num_warps":"4","output_tiles":[{"sizes":["64","64"]}],"num_ctas":1,"num_stages":4,"is_tma_allowed":false,"is_warp_specialization_allowed":false}},"force_earliest_schedule":false,"reification_cost":[],"device_type":"DEVICE_TYPE_INVALID"}
# E0512 21:31:36.451647  744538 xtile_compiler.cc:401] Computation: gemm_fusion_dot.455_computation.clone {
#   parameter_0.4 = bf16[1536,512]{1,0} parameter(0)
#   parameter_1.4 = bf16[1536,512]{1,0} parameter(1)
#   concatenate.461 = bf16[1536,1024]{1,0} concatenate(parameter_0.4, parameter_1.4), dimensions={1}
#   bitcast.7780 = bf16[1024,1536]{0,1} bitcast(concatenate.461)
#   parameter_2.3 = f32[1536,4096]{1,0} parameter(2)
#   convert_element_type.5230 = bf16[1536,4096]{1,0} convert(parameter_2.3)
#   ROOT dot.546 = bf16[1024,4096]{0,1} dot(bitcast.7780, convert_element_type.5230), lhs_contracting_dims={1}, rhs_contracting_dims={0}, backend_config={"sizes":["64"]}
# }
# E0512 21:31:36.602222  744540 xtile_compiler.cc:399] Fusion: gemm_fusion_dot.466 = bf16[16384,1536]{0,1} fusion(bitcast.128, bitcast.175, linear_embedding____w__.9), kind=kCustom, calls=gemm_fusion_dot.466_computation.clone, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"fusion_backend_config":{"kind":"__triton_nested_gemm_fusion","block_level_fusion_config":{"num_warps":"8","output_tiles":[{"sizes":["128","256"]}],"num_ctas":1,"num_stages":4,"is_tma_allowed":false,"is_warp_specialization_allowed":false}},"force_earliest_schedule":false,"reification_cost":[],"device_type":"DEVICE_TYPE_INVALID"}
# E0512 21:31:36.602354  744540 xtile_compiler.cc:401] Computation: gemm_fusion_dot.466_computation.clone {
#   parameter_0.33 = bf16[8192,1536]{1,0} parameter(0)
#   parameter_1.33 = bf16[8192,1536]{1,0} parameter(1)
#   concatenate.466 = bf16[16384,1536]{1,0} concatenate(parameter_0.33, parameter_1.33), dimensions={0}
#   parameter_2.8 = f32[1536,1536]{1,0} parameter(2)
#   convert_element_type.5238 = bf16[1536,1536]{1,0} convert(parameter_2.8)
#   ROOT dot.575 = bf16[16384,1536]{0,1} dot(concatenate.466, convert_element_type.5238), lhs_contracting_dims={1}, rhs_contracting_dims={0}, backend_config={"sizes":["32"]}
# }
# E0512 21:31:36.981642  744541 xtile_compiler.cc:399] Fusion: gemm_fusion_dot.466 = bf16[16384,1536]{0,1} fusion(bitcast.128, bitcast.175, linear_embedding____w__.9), kind=kCustom, calls=gemm_fusion_dot.466_computation.clone, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"fusion_backend_config":{"kind":"__triton_nested_gemm_fusion","block_level_fusion_config":{"num_warps":"2","output_tiles":[{"sizes":["64","32"]}],"num_ctas":1,"num_stages":3,"is_tma_allowed":false,"is_warp_specialization_allowed":false}},"force_earliest_schedule":false,"reification_cost":[],"device_type":"DEVICE_TYPE_INVALID"}
# E0512 21:31:36.981774  744541 xtile_compiler.cc:401] Computation: gemm_fusion_dot.466_computation.clone {
#   parameter_0.33 = bf16[8192,1536]{1,0} parameter(0)
#   parameter_1.33 = bf16[8192,1536]{1,0} parameter(1)
#   concatenate.466 = bf16[16384,1536]{1,0} concatenate(parameter_0.33, parameter_1.33), dimensions={0}
#   parameter_2.8 = f32[1536,1536]{1,0} parameter(2)
#   convert_element_type.5238 = bf16[1536,1536]{1,0} convert(parameter_2.8)
#   ROOT dot.575 = bf16[16384,1536]{0,1} dot(concatenate.466, convert_element_type.5238), lhs_contracting_dims={1}, rhs_contracting_dims={0}, backend_config={"sizes":["128"]}
# }
# E0512 21:31:37.346333  744542 xtile_compiler.cc:399] Fusion: gemm_fusion_dot.455 = f32[4,1024,4096]{1,2,0} fusion(bitcast.2139, bitcast.2157, bitcast.2), kind=kCustom, calls=gemm_fusion_dot.455_computation.clone, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"fusion_backend_config":{"kind":"__triton_nested_gemm_fusion","block_level_fusion_config":{"num_warps":"8","output_tiles":[{"sizes":["1","128","128"]}],"num_ctas":1,"num_stages":4,"is_tma_allowed":false,"is_warp_specialization_allowed":false}},"force_earliest_schedule":false,"reification_cost":[],"device_type":"DEVICE_TYPE_INVALID"}
# E0512 21:31:37.346475  744542 xtile_compiler.cc:401] Computation: gemm_fusion_dot.455_computation.clone {
#   parameter_0.4 = bf16[1536,512]{1,0} parameter(0)
#   parameter_1.4 = bf16[1536,512]{1,0} parameter(1)
#   concatenate.461 = bf16[1536,1024]{1,0} concatenate(parameter_0.4, parameter_1.4), dimensions={1}
#   bitcast.7780 = bf16[1024,4,384]{0,2,1} bitcast(concatenate.461)
#   parameter_2.3 = f32[4,384,4096]{2,1,0} parameter(2)
#   convert_element_type.5230 = bf16[4,384,4096]{2,1,0} convert(parameter_2.3)
#   ROOT dot = f32[4,1024,4096]{1,2,0} dot(bitcast.7780, convert_element_type.5230), lhs_batch_dims={1}, lhs_contracting_dims={2}, rhs_batch_dims={0}, rhs_contracting_dims={1}, backend_config={"sizes":["32"]}
# }
# E0512 21:31:37.759528  744550 xtile_compiler.cc:399] Fusion: gemm_fusion_dot.464 = f32[8,1024,128]{2,1,0} fusion(bitcast.2239, bitcast.2264, bitcast.2), kind=kCustom, calls=gemm_fusion_dot.464_computation.clone, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"fusion_backend_config":{"kind":"__triton_nested_gemm_fusion","block_level_fusion_config":{"num_warps":"4","output_tiles":[{"sizes":["1","64","128"]}],"num_ctas":1,"num_stages":4,"is_tma_allowed":false,"is_warp_specialization_allowed":false}},"force_earliest_schedule":false,"reification_cost":[],"device_type":"DEVICE_TYPE_INVALID"}
# E0512 21:31:37.759610  744550 xtile_compiler.cc:401] Computation: gemm_fusion_dot.464_computation.clone {
#   parameter_0.10 = bf16[1536,512]{1,0} parameter(0)
#   parameter_1.10 = bf16[1536,512]{1,0} parameter(1)
#   concatenate.464 = bf16[1536,1024]{1,0} concatenate(parameter_0.10, parameter_1.10), dimensions={1}
#   bitcast.7787 = bf16[1024,8,192]{0,2,1} bitcast(concatenate.464)
#   parameter_2.6 = f32[8,192,128]{2,1,0} parameter(2)
#   convert_element_type.5232 = bf16[8,192,128]{2,1,0} convert(parameter_2.6)
#   ROOT dot = f32[8,1024,128]{2,1,0} dot(bitcast.7787, convert_element_type.5232), lhs_batch_dims={1}, lhs_contracting_dims={2}, rhs_batch_dims={0}, rhs_contracting_dims={1}, backend_config={"sizes":["32"]}
# }
# E0512 21:31:38.171851  744550 xtile_compiler.cc:399] Fusion: gemm_fusion_dot.454 = bf16[16384,1024]{1,0} fusion(bitcast.1679, bitcast.2089, q_layer____w__.9), kind=kCustom, calls=gemm_fusion_dot.454_computation.clone, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"fusion_backend_config":{"kind":"__triton_nested_gemm_fusion","block_level_fusion_config":{"num_warps":"8","output_tiles":[{"sizes":["128","128"]}],"num_ctas":1,"num_stages":4,"is_tma_allowed":false,"is_warp_specialization_allowed":false}},"force_earliest_schedule":false,"reification_cost":[],"device_type":"DEVICE_TYPE_INVALID"}
# E0512 21:31:38.172071  744550 xtile_compiler.cc:401] Computation: gemm_fusion_dot.454_computation.clone {
#   parameter_0.2 = bf16[1536,8192]{1,0} parameter(0)
#   parameter_1.2 = bf16[1536,8192]{1,0} parameter(1)
#   concatenate.460 = bf16[1536,16384]{1,0} concatenate(parameter_0.2, parameter_1.2), dimensions={1}
#   bitcast.7775 = bf16[16384,1536]{0,1} bitcast(concatenate.460)
#   parameter_2.2 = f32[1536,1024]{1,0} parameter(2)
#   convert_element_type.5229 = bf16[1536,1024]{1,0} convert(parameter_2.2)
#   ROOT dot.544 = bf16[16384,1024]{1,0} dot(bitcast.7775, convert_element_type.5229), lhs_contracting_dims={1}, rhs_contracting_dims={0}, backend_config={"sizes":["32"]}
# }
# E0512 21:31:38.188837  744549 xtile_compiler.cc:399] Fusion: gemm_fusion_dot.466 = bf16[16384,1536]{0,1} fusion(bitcast.128, bitcast.175, linear_embedding____w__.9), kind=kCustom, calls=gemm_fusion_dot.466_computation.clone, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"fusion_backend_config":{"kind":"__triton_nested_gemm_fusion","block_level_fusion_config":{"num_warps":"4","output_tiles":[{"sizes":["64","64"]}],"num_ctas":1,"num_stages":4,"is_tma_allowed":false,"is_warp_specialization_allowed":false}},"force_earliest_schedule":false,"reification_cost":[],"device_type":"DEVICE_TYPE_INVALID"}
# E0512 21:31:38.188938  744549 xtile_compiler.cc:401] Computation: gemm_fusion_dot.466_computation.clone {
#   parameter_0.33 = bf16[8192,1536]{1,0} parameter(0)
#   parameter_1.33 = bf16[8192,1536]{1,0} parameter(1)
#   concatenate.466 = bf16[16384,1536]{1,0} concatenate(parameter_0.33, parameter_1.33), dimensions={0}
#   parameter_2.8 = f32[1536,1536]{1,0} parameter(2)
#   convert_element_type.5238 = bf16[1536,1536]{1,0} convert(parameter_2.8)
#   ROOT dot.575 = bf16[16384,1536]{0,1} dot(concatenate.466, convert_element_type.5238), lhs_contracting_dims={1}, rhs_contracting_dims={0}, backend_config={"sizes":["64"]}
# }
# E0512 21:31:38.284591  744550 xtile_compiler.cc:399] Fusion: gemm_fusion_dot.455 = bf16[1024,4096]{0,1} fusion(bitcast.2139, bitcast.2157, linear_k____w__.11), kind=kCustom, calls=gemm_fusion_dot.455_computation.clone, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"fusion_backend_config":{"kind":"__triton_nested_gemm_fusion","block_level_fusion_config":{"num_warps":"4","output_tiles":[{"sizes":["64","64"]}],"num_ctas":1,"num_stages":3,"is_tma_allowed":false,"is_warp_specialization_allowed":false}},"force_earliest_schedule":false,"reification_cost":[],"device_type":"DEVICE_TYPE_INVALID"}
# E0512 21:31:38.284752  744550 xtile_compiler.cc:401] Computation: gemm_fusion_dot.455_computation.clone {
#   parameter_0.4 = bf16[1536,512]{1,0} parameter(0)
#   parameter_1.4 = bf16[1536,512]{1,0} parameter(1)
#   concatenate.461 = bf16[1536,1024]{1,0} concatenate(parameter_0.4, parameter_1.4), dimensions={1}
#   bitcast.7780 = bf16[1024,1536]{0,1} bitcast(concatenate.461)
#   parameter_2.3 = f32[1536,4096]{1,0} parameter(2)
#   convert_element_type.5230 = bf16[1536,4096]{1,0} convert(parameter_2.3)
#   ROOT dot.546 = bf16[1024,4096]{0,1} dot(bitcast.7780, convert_element_type.5230), lhs_contracting_dims={1}, rhs_contracting_dims={0}, backend_config={"sizes":["128"]}
# }
# E0512 21:31:38.338701  744549 xtile_compiler.cc:399] Fusion: gemm_fusion_dot.466 = bf16[16384,1536]{0,1} fusion(bitcast.128, bitcast.175, linear_embedding____w__.9), kind=kCustom, calls=gemm_fusion_dot.466_computation.clone, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"fusion_backend_config":{"kind":"__triton_nested_gemm_fusion","block_level_fusion_config":{"num_warps":"4","output_tiles":[{"sizes":["64","128"]}],"num_ctas":1,"num_stages":3,"is_tma_allowed":false,"is_warp_specialization_allowed":false}},"force_earliest_schedule":false,"reification_cost":[],"device_type":"DEVICE_TYPE_INVALID"}
# E0512 21:31:38.338828  744549 xtile_compiler.cc:401] Computation: gemm_fusion_dot.466_computation.clone {
#   parameter_0.33 = bf16[8192,1536]{1,0} parameter(0)
#   parameter_1.33 = bf16[8192,1536]{1,0} parameter(1)
#   concatenate.466 = bf16[16384,1536]{1,0} concatenate(parameter_0.33, parameter_1.33), dimensions={0}
#   parameter_2.8 = f32[1536,1536]{1,0} parameter(2)
#   convert_element_type.5238 = bf16[1536,1536]{1,0} convert(parameter_2.8)
#   ROOT dot.575 = bf16[16384,1536]{0,1} dot(concatenate.466, convert_element_type.5238), lhs_contracting_dims={1}, rhs_contracting_dims={0}, backend_config={"sizes":["64"]}
# }
# E0512 21:31:38.500167  744536 xtile_compiler.cc:399] Fusion: gemm_fusion_dot.454 = bf16[16384,1024]{1,0} fusion(bitcast.1679, bitcast.2089, q_layer____w__.9), kind=kCustom, calls=gemm_fusion_dot.454_computation.clone, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"fusion_backend_config":{"kind":"__triton_nested_gemm_fusion","block_level_fusion_config":{"num_warps":"4","output_tiles":[{"sizes":["64","128"]}],"num_ctas":1,"num_stages":3,"is_tma_allowed":false,"is_warp_specialization_allowed":false}},"force_earliest_schedule":false,"reification_cost":[],"device_type":"DEVICE_TYPE_INVALID"}
# E0512 21:31:38.500265  744536 xtile_compiler.cc:401] Computation: gemm_fusion_dot.454_computation.clone {
#   parameter_0.2 = bf16[1536,8192]{1,0} parameter(0)
#   parameter_1.2 = bf16[1536,8192]{1,0} parameter(1)
#   concatenate.460 = bf16[1536,16384]{1,0} concatenate(parameter_0.2, parameter_1.2), dimensions={1}
#   bitcast.7775 = bf16[16384,1536]{0,1} bitcast(concatenate.460)
#   parameter_2.2 = f32[1536,1024]{1,0} parameter(2)
#   convert_element_type.5229 = bf16[1536,1024]{1,0} convert(parameter_2.2)
#   ROOT dot.544 = bf16[16384,1024]{1,0} dot(bitcast.7775, convert_element_type.5229), lhs_contracting_dims={1}, rhs_contracting_dims={0}, backend_config={"sizes":["64"]}
# }
# E0512 21:31:38.986346  744550 xtile_compiler.cc:399] Fusion: gemm_fusion_dot.454 = bf16[16384,1024]{1,0} fusion(bitcast.1679, bitcast.2089, q_layer____w__.9), kind=kCustom, calls=gemm_fusion_dot.454_computation.clone, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"fusion_backend_config":{"kind":"__triton_nested_gemm_fusion","block_level_fusion_config":{"num_warps":"4","output_tiles":[{"sizes":["64","64"]}],"num_ctas":1,"num_stages":3,"is_tma_allowed":false,"is_warp_specialization_allowed":false}},"force_earliest_schedule":false,"reification_cost":[],"device_type":"DEVICE_TYPE_INVALID"}
# E0512 21:31:38.986472  744550 xtile_compiler.cc:401] Computation: gemm_fusion_dot.454_computation.clone {
#   parameter_0.2 = bf16[1536,8192]{1,0} parameter(0)
#   parameter_1.2 = bf16[1536,8192]{1,0} parameter(1)
#   concatenate.460 = bf16[1536,16384]{1,0} concatenate(parameter_0.2, parameter_1.2), dimensions={1}
#   bitcast.7775 = bf16[16384,1536]{0,1} bitcast(concatenate.460)
#   parameter_2.2 = f32[1536,1024]{1,0} parameter(2)
#   convert_element_type.5229 = bf16[1536,1024]{1,0} convert(parameter_2.2)
#   ROOT dot.544 = bf16[16384,1024]{1,0} dot(bitcast.7775, convert_element_type.5229), lhs_contracting_dims={1}, rhs_contracting_dims={0}, backend_config={"sizes":["128"]}
# }
# E0512 21:31:40.480616  744542 xtile_compiler.cc:399] Fusion: gemm_fusion_dot.454 = bf16[16384,1024]{1,0} fusion(bitcast.1679, bitcast.2089, q_layer____w__.9), kind=kCustom, calls=gemm_fusion_dot.454_computation.clone, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"fusion_backend_config":{"kind":"__triton_nested_gemm_fusion","block_level_fusion_config":{"num_warps":"2","output_tiles":[{"sizes":["64","32"]}],"num_ctas":1,"num_stages":3,"is_tma_allowed":false,"is_warp_specialization_allowed":false}},"force_earliest_schedule":false,"reification_cost":[],"device_type":"DEVICE_TYPE_INVALID"}
# E0512 21:31:40.480737  744542 xtile_compiler.cc:401] Computation: gemm_fusion_dot.454_computation.clone {
#   parameter_0.2 = bf16[1536,8192]{1,0} parameter(0)
#   parameter_1.2 = bf16[1536,8192]{1,0} parameter(1)
#   concatenate.460 = bf16[1536,16384]{1,0} concatenate(parameter_0.2, parameter_1.2), dimensions={1}
#   bitcast.7775 = bf16[16384,1536]{0,1} bitcast(concatenate.460)
#   parameter_2.2 = f32[1536,1024]{1,0} parameter(2)
#   convert_element_type.5229 = bf16[1536,1024]{1,0} convert(parameter_2.2)
#   ROOT dot.544 = bf16[16384,1024]{1,0} dot(bitcast.7775, convert_element_type.5229), lhs_contracting_dims={1}, rhs_contracting_dims={0}, backend_config={"sizes":["128"]}
# }
# E0512 21:31:52.772753  744541 cuda_timer.cc:87] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 100%|██████████| 10/10 [01:30<00:00,  9.04s/it]

# %%
# first variant positive strand only
variant_scores_dic[unique_variants[0]] # score per gene per ontology (per gtex_tissue)
# Out:
#             variant_id         scored_interval          gene_id gene_name  \
# 0     chr3:4491276:T>C  chr3:3966988-5015564:.  ENSG00000144455     SUMF1
# 1     chr3:4491276:T>C  chr3:3966988-5015564:.  ENSG00000144455     SUMF1
# 2     chr3:4491276:T>C  chr3:3966988-5015564:.  ENSG00000144455     SUMF1
# 3     chr3:4491276:T>C  chr3:3966988-5015564:.  ENSG00000144455     SUMF1
# 4     chr3:4491276:T>C  chr3:3966988-5015564:.  ENSG00000144455     SUMF1
# ...                ...                     ...              ...       ...
# 5143  chr3:4491276:T>C  chr3:3966988-5015564:.  ENSG00000134107   BHLHE40
# 5144  chr3:4491276:T>C  chr3:3966988-5015564:.  ENSG00000134107   BHLHE40
# 5145  chr3:4491276:T>C  chr3:3966988-5015564:.  ENSG00000134107   BHLHE40
# 5146  chr3:4491276:T>C  chr3:3966988-5015564:.  ENSG00000134107   BHLHE40
# 5147  chr3:4491276:T>C  chr3:3966988-5015564:.  ENSG00000134107   BHLHE40
#
#            gene_type gene_strand junction_Start junction_End output_type  \
# 0     protein_coding           -           None         None     RNA_SEQ
# 1     protein_coding           -           None         None     RNA_SEQ
# 2     protein_coding           -           None         None     RNA_SEQ
# 3     protein_coding           -           None         None     RNA_SEQ
# 4     protein_coding           -           None         None     RNA_SEQ
# ...              ...         ...            ...          ...         ...
# 5143  protein_coding           +           None         None     RNA_SEQ
# 5144  protein_coding           +           None         None     RNA_SEQ
# 5145  protein_coding           +           None         None     RNA_SEQ
# 5146  protein_coding           +           None         None     RNA_SEQ
# 5147  protein_coding           +           None         None     RNA_SEQ
#
#                                    variant_scorer  ...         Assay title  \
# 0     GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...  polyA plus RNA-seq
# 1     GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...       total RNA-seq
# 2     GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...  polyA plus RNA-seq
# 3     GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...       total RNA-seq
# 4     GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...       total RNA-seq
# ...                                           ...  ...                 ...
# 5143  GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...  polyA plus RNA-seq
# 5144  GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...  polyA plus RNA-seq
# 5145  GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...  polyA plus RNA-seq
# 5146  GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...  polyA plus RNA-seq
# 5147  GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...  polyA plus RNA-seq
#
#       ontology_curie                   biosample_name  \
# 0         CL:0000047               neuronal stem cell
# 1         CL:0000062                       osteoblast
# 2         CL:0000084                           T-cell
# 3         CL:0000084                           T-cell
# 4         CL:0000115                 endothelial cell
# ...              ...                              ...
# 5143  UBERON:0018115                left renal pelvis
# 5144  UBERON:0018116               right renal pelvis
# 5145  UBERON:0018117   left renal cortex interstitium
# 5146  UBERON:0018118  right renal cortex interstitium
# 5147  UBERON:0036149                  suprapubic skin
#
#                      biosample_type biosample_life_stage  \
# 0     in_vitro_differentiated_cells            embryonic
# 1                      primary_cell                adult
# 2                      primary_cell                adult
# 3                      primary_cell                adult
# 4     in_vitro_differentiated_cells                adult
# ...                             ...                  ...
# 5143                         tissue            embryonic
# 5144                         tissue            embryonic
# 5145                         tissue            embryonic
# 5146                         tissue            embryonic
# 5147                         tissue                adult
#
#                           gtex_tissue data_source endedness  \
# 0                                          encode    paired
# 1                                          encode    paired
# 2                                          encode    paired
# 3                                          encode    single
# 4                                          encode    single
# ...                               ...         ...       ...
# 5143                                       encode    single
# 5144                                       encode    single
# 5145                                       encode    single
# 5146                                       encode    single
# 5147  Skin_Not_Sun_Exposed_Suprapubic        gtex    paired
#
#      genetically_modified raw_score
# 0                   False  0.000529
# 1                   False  0.003274
# 2                   False  0.002539
# 3                   False  0.002098
# 4                   False  0.001375
# ...                   ...       ...
# 5143                False  0.000130
# 5144                False  0.000068
# 5145                False  0.000058
# 5146                False -0.000103
# 5147                False  0.000499
#
# [5148 rows x 22 columns]

# %% [markdown]
# For the reproduction the raw results need to be filtered according to the Alphagenome data

# %%
df_coefficient_results = []

for row_nr in range(len(df_coefficient)):
    row = df_coefficient.iloc[row_nr]
    variant = row.variant_id
    
    if variant not in variant_scores_dic:
        continue
    
    variant_scores = variant_scores_dic[variant]
    
    mask = (
        (variant_scores["gene_id"] == row.gene_id.split('.')[0]) &
        (variant_scores["gtex_tissue"] == row.tissue)
    )

    filtered = variant_scores.loc[mask, "raw_score"]

    new_prediction = filtered.iloc[0] if not filtered.empty else np.nan
    # add prediction from model to the row and then collect row in a new dataframe for all variants
    new_row = row.copy()
    new_row['prediction_new'] = new_prediction

    df_coefficient_results.append(new_row)

# %%
df_coefficient_results = pd.DataFrame(df_coefficient_results)
df_coefficient_results.head()
# Out:
#              variant_id             gene_id                tissue  prediction  \
# 0  chr3_4491276_T_C_b38   ENSG00000231249.3  Adipose_Subcutaneous    0.101731
# 1  chr3_8733693_G_T_b38   ENSG00000182533.7  Adipose_Subcutaneous    0.014747
# 2  chr3_8963418_C_T_b38  ENSG00000070950.10  Adipose_Subcutaneous   -0.095976
# 3  chr3_9867065_G_C_b38  ENSG00000187288.12  Adipose_Subcutaneous   -0.000609
# 4  chr3_9903375_C_T_b38  ENSG00000163701.19  Adipose_Subcutaneous   -0.035684
#
#      target                                     variant_scorer output_type  \
# 0  0.279811  gene_exons_contained_diff_mean;OutputType.RNA_...     RNA_SEQ
# 1  0.567912  gene_exons_contained_diff_mean;OutputType.RNA_...     RNA_SEQ
# 2 -0.684296  gene_exons_contained_diff_mean;OutputType.RNA_...     RNA_SEQ
# 3 -0.130677  gene_exons_contained_diff_mean;OutputType.RNA_...     RNA_SEQ
# 4 -0.660048  gene_exons_contained_diff_mean;OutputType.RNA_...     RNA_SEQ
#
#                      metric_calculator metric_name  prediction_new
# 0  TissueAggregatedAnnDataCorrelations        None        0.101413
# 1  TissueAggregatedAnnDataCorrelations        None       -0.003065
# 2  TissueAggregatedAnnDataCorrelations        None       -0.093998
# 3  TissueAggregatedAnnDataCorrelations        None       -0.006357
# 4  TissueAggregatedAnnDataCorrelations        None       -0.021460

# %%
# CDS cor exon
import pandas as pd
import matplotlib.pyplot as plt

x = df_coefficient_results["prediction"]
y = df_coefficient_results["prediction_new"]

# Correlation
corr = x.corr(y)

print("Pearson correlation:", corr)

# Plot
plt.figure(figsize=(6,6))
plt.scatter(x, y, alpha=0.5)

plt.xlabel("alphaGenome prediction")
plt.ylabel("alphaGenome new prediction")
plt.title(f"Correlation = {corr:.4f}")

plt.show()
# Out:
# Pearson correlation: 0.9960793272256234

# %% [markdown]
# ```python
# params: hk.Params,
# state: hk.State,
# apply_fn: ApplyFn,
# junctions_apply_fn: JunctionsApplyFn,
# metadata: Mapping[dna_model.Organism, AlphaGenomeOutputMetadata],
# fasta_extractors: (
#     Mapping[dna_model.Organism, fasta.FastaExtractor] | None
# ) = None,
# splice_site_extractors: (
#     Mapping[dna_model.Organism, splicing_io.SpliceSiteAnnotationExtractor]
#     | None
# ) = None,
# gtfs: Mapping[dna_model.Organism, pd.DataFrame] | None = None,
# pas_gtfs: Mapping[dna_model.Organism, pd.DataFrame] | None = None,
# num_splice_sites: int = 512,
# splice_site_threshold: float = 0.1,
# device: jax.Device | None = None,
# ```
